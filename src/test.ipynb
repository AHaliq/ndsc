# %% [markdown]
# ## Add category group column to data

# %%
import pandas as pd
import googleutil as G
import cleaners as cln

d = pd.read_csv(G.sou + 'train.csv')
cln.data_addgroup(d)
d.head()
#data.to_csv('./data/clean/train_group.csv')
# export
# Out:
#     itemid                                              title  Category  \
# 0   307504               nyx sex bomb pallete natural palette         0
# 1   461203  etude house precious mineral any cushion pearl...         1
# 2  3592295                           milani rose powder blush         2
# 3  4460167                etude house baby sweet sugar powder         3
# 4  5853995       bedak revlon color stay aqua mineral make up         3
#
#                                           image_path  group
# 0  beauty_image/6b2e9cbb279ac95703348368aa65da09.jpg      2
# 1  beauty_image/20450222d857c9571ba8fa23bdedc8c9.jpg      2
# 2  beauty_image/6a5962bed605a3dd6604ca3a4278a4f9.jpg      2
# 3  beauty_image/56987ae186e8a8e71fcc5a261ca485da.jpg      2
# 4  beauty_image/9c6968066ebab57588c2f757a240d8b9.jpg      2

# %%
gdat = pd.read_csv('/Users/haliq/Documents/dev/python/ndsc/data/clean/train_group.csv')
gdat.head()
# Out:
#    Unnamed: 0   itemid                                              title  \
# 0           0   307504               nyx sex bomb pallete natural palette
# 1           1   461203  etude house precious mineral any cushion pearl...
# 2           2  3592295                           milani rose powder blush
# 3           3  4460167                etude house baby sweet sugar powder
# 4           4  5853995       bedak revlon color stay aqua mineral make up
#
#    Category                                         image_path  group
# 0         0  beauty_image/6b2e9cbb279ac95703348368aa65da09.jpg      2
# 1         1  beauty_image/20450222d857c9571ba8fa23bdedc8c9.jpg      2
# 2         2  beauty_image/6a5962bed605a3dd6604ca3a4278a4f9.jpg      2
# 3         3  beauty_image/56987ae186e8a8e71fcc5a261ca485da.jpg      2
# 4         3  beauty_image/9c6968066ebab57588c2f757a240d8b9.jpg      2

# %%
from PIL import Image
import requests
from io import BytesIO
from matplotlib.pyplot import imshow
import numpy as np

url = 'http://storage.googleapis.com/ndsc-storage/data/images/beauty_image/0a0a91addbc1fcdc06735a47d2ce330c.jpg'
#url = G.img + 'fashion_image/000006831bfaf0e3b5ce3564a10e6dd4.jpg'
#gdat['image_path'][4]

response = requests.get(url)
img = Image.open(BytesIO(response.content))
imshow(np.asarray(img))
w, h = img.size
w
# Out:
# 800

# %%
size = 128, 128
img.thumbnail(size, Image.ANTIALIAS)
imshow(np.asarray(img))

# %%
url
# Out:
# 'http://storage.googleapis.com/ndsc-storage/data/images/beauty_image/2b2140011dd4eac3fc65efe325e71b86.jpg'
